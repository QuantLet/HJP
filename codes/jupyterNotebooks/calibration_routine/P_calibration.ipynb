# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kurtosis, skew, norm
from scipy.optimize import minimize
from numba import njit
from typing import Tuple, Optional
from enum import Enum
import qis
from dataclasses import fields, replace, asdict
from datetime import datetime, timedelta
import scipy.stats as ss
import copy
import scipy

from scipy.interpolate import splrep, BSpline
from numba.typed import List

# analytics
import sys
sys.path.insert(0,'../../') # just for jupyter  notebook
from stochvolmodels.pricers.hawkes_jd_pricer import HawkesJDParams, HawkesJDPricer, hawkesjd_chain_pricer, unpack_and_transform_pars_for_measure_change, unpack_pars

import tensorflow.experimental.numpy as tnp
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from stochvolmodels.data.test_option_chain import get_btc_test_chain_data, get_gld_test_chain_data_6m, get_sqqq_test_chain_data, get_spy_test_chain_data
from stochvolmodels.utils.funcs import to_flat_np_array, set_time_grid, timer, set_seed, transform_to_tfcomplex128, transform_from_tfcomplex128_to_np, slice_option_chain
from stochvolmodels.data.option_chain import OptionChain

import os
from stochvolmodels.pricers.core.bsm_pricer import infer_bsm_implied_vol, compute_bsm_price
import warnings
from stochvolmodels.MLE_estimator import hawkes_jd
from stochvolmodels.MLE_estimator import hawkes_jd_weekday

import pickle
warnings.filterwarnings('ignore')
# Out:
# 2023-12-14 14:22:58.669739: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Read BTC spot
freq = 'D'

df = pd.read_csv('../../../resources/deribit/BTC-spot-combined.csv')
_id = pd.to_datetime(df.timestamp).apply(lambda x: x.hour) == 0

df = df.loc[_id, :]
df.timestamp = df.timestamp.apply(lambda x: x[:10])
df.timestamp = pd.to_datetime(df.timestamp)
price = df.spot
price.index = df.timestamp

returns = np.log(price/price.shift(1))[1:]

if freq == 'D':  
    dt = 1/365

elif freq == 'W':
    dt = 1/365*7

# Use BTC prior to option start day to calibrate for model parameters
_id = price.index <= options_start
MLE_estimator_daily = hawkes_jd.Hawkes_MLE_estimator(price.loc[_id])

# %%
# Run POT
nu_p_grid = np.linspace(-.18, .18, 21)
nu_m_grid = np.linspace(-.18, .18, 21)

POT_results = []
for nu_p in nu_p_grid:
    for nu_m in nu_p_grid:
        if nu_p < nu_m:
            continue
        MLE_estimator_daily.run_Peak_over_Thresholds(nu_m, nu_p, verbose=False)
        POT_results.append({'nu_p0':nu_p, 'nu_m0':nu_m,
                            'nu_p':MLE_estimator_daily.nu_p, 'nu_m':MLE_estimator_daily.nu_m, 
                            'eta_p':MLE_estimator_daily.eta_p, 'eta_m':MLE_estimator_daily.eta_m,
                            'skew':ss.skew(MLE_estimator_daily.diffusion), 
                            'kurt':ss.kurtosis(MLE_estimator_daily.diffusion),
                            'n_pos_jumps':len(MLE_estimator_daily.positive_jumps_path), 
                            'n_neg_jumps':len(MLE_estimator_daily.negative_jumps_path), 
                            'percentage_diffusion':len(MLE_estimator_daily.diffusion)/len(MLE_estimator_daily.price)})
        
        
POT_results = pd.DataFrame(POT_results)
POT_results.loc[:,'error'] = (POT_results.loc[:, 'skew']**2) + (POT_results.loc[:, 'kurt'])**2
# print('daily nu_p:', MLE_estimator_daily.nu_p)
# print('daily nu_m:', MLE_estimator_daily.nu_m)
# Out:
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 15
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1231
# # neg jumps obs: 23
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1182
# # pos jumps obs: 0
# # neg jumps obs: 64
# Skewness of diffusion obs: 1.1948171649366446
# Excess kurtosis of diffusion obs: 4.399805809888195
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 15
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 65
# # pos jumps obs: 1168
# # neg jumps obs: 13
# Skewness of diffusion obs: -0.8146369350718874
# Excess kurtosis of diffusion obs: -0.056878124147719866
# # diffusion obs: 56
# # pos jumps obs: 1177
# # neg jumps obs: 13
# Skewness of diffusion obs: -0.8235575566198378
# Excess kurtosis of diffusion obs: -0.06401810321433254
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 143
# # pos jumps obs: 1086
# # neg jumps obs: 17
# Skewness of diffusion obs: -0.9413088619493255
# Excess kurtosis of diffusion obs: -0.0015747563087566974
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 143
# # pos jumps obs: 1086
# # neg jumps obs: 17
# Skewness of diffusion obs: -0.9413088619493255
# Excess kurtosis of diffusion obs: -0.0015747563087566974
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 188
# # pos jumps obs: 1038
# # neg jumps obs: 20
# Skewness of diffusion obs: -0.8542575406787815
# Excess kurtosis of diffusion obs: -0.011591345393337615
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 23
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 178
# # pos jumps obs: 1049
# # neg jumps obs: 19
# Skewness of diffusion obs: -0.8656138282719719
# Excess kurtosis of diffusion obs: -0.007202120357707731
# # diffusion obs: 175
# # pos jumps obs: 1052
# # neg jumps obs: 19
# Skewness of diffusion obs: -0.8652001350241816
# Excess kurtosis of diffusion obs: -0.0121623185745392
# # diffusion obs: 12
# # pos jumps obs: 1039
# # neg jumps obs: 195
# Skewness of diffusion obs: -0.2557286704383837
# Excess kurtosis of diffusion obs: -0.18748384840957444
# # diffusion obs: 299
# # pos jumps obs: 923
# # neg jumps obs: 24
# Skewness of diffusion obs: -0.9178799208663309
# Excess kurtosis of diffusion obs: -0.01525596329720491
# # diffusion obs: 188
# # pos jumps obs: 1038
# # neg jumps obs: 20
# Skewness of diffusion obs: -0.8542575406787815
# Excess kurtosis of diffusion obs: -0.011591345393337615
# # diffusion obs: 32
# # pos jumps obs: 1048
# # neg jumps obs: 166
# Skewness of diffusion obs: -0.41999161315217387
# Excess kurtosis of diffusion obs: -0.17531000985618705
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1246
# # pos jumps obs: 0
# # neg jumps obs: 0
# Skewness of diffusion obs: -0.26692284300326885
# Excess kurtosis of diffusion obs: 3.8806882294768936
# # diffusion obs: 438
# # pos jumps obs: 668
# # neg jumps obs: 140
# Skewness of diffusion obs: -0.9657537191401003
# Excess kurtosis of diffusion obs: -0.0011726962071008096
# # diffusion obs: 19
# # pos jumps obs: 1093
# # neg jumps obs: 134
# Skewness of diffusion obs: -0.004777212930787733
# Excess kurtosis of diffusion obs: -0.14177596980531426
# # diffusion obs: 20
# # pos jumps obs: 1093
# # neg jumps obs: 133
# Skewness of diffusion obs: -0.2231988469606539
# Excess kurtosis of diffusion obs: -0.18009043431927552
# # diffusion obs: 20
# # pos jumps obs: 1092
# # neg jumps obs: 134
# Skewness of diffusion obs: 0.09521257491462982
# Excess kurtosis of diffusion obs: -0.32448854842798447
# # diffusion obs: 438
# # pos jumps obs: 668
# # neg jumps obs: 140
# Skewness of diffusion obs: -0.9657537191401003
# Excess kurtosis of diffusion obs: -0.0011726962071008096
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 843
# # pos jumps obs: 0
# # neg jumps obs: 403
# Skewness of diffusion obs: 2.359507971753498
# Excess kurtosis of diffusion obs: 8.170312640363676
# # diffusion obs: 20
# # pos jumps obs: 1093
# # neg jumps obs: 133
# Skewness of diffusion obs: -0.2231988469606539
# Excess kurtosis of diffusion obs: -0.18009043431927552
# # diffusion obs: 438
# # pos jumps obs: 668
# # neg jumps obs: 140
# Skewness of diffusion obs: -0.9657537191401003
# Excess kurtosis of diffusion obs: -0.0011726962071008096
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1246
# # pos jumps obs: 0
# # neg jumps obs: 0
# Skewness of diffusion obs: -0.26692284300326885
# Excess kurtosis of diffusion obs: 3.8806882294768936
# # diffusion obs: 746
# # pos jumps obs: 348
# # neg jumps obs: 152
# Skewness of diffusion obs: -0.7285713450405945
# Excess kurtosis of diffusion obs: -0.0023335651881364328
# # diffusion obs: 0
# # pos jumps obs: 568
# # neg jumps obs: 848
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 759
# # pos jumps obs: 336
# # neg jumps obs: 151
# Skewness of diffusion obs: -0.7167723246931135
# Excess kurtosis of diffusion obs: -0.00022843323957122408
# # diffusion obs: 684
# # pos jumps obs: 298
# # neg jumps obs: 264
# Skewness of diffusion obs: 0.001346866268379852
# Excess kurtosis of diffusion obs: -0.8141606872705962
# # diffusion obs: 746
# # pos jumps obs: 348
# # neg jumps obs: 152
# Skewness of diffusion obs: -0.7285713450405945
# Excess kurtosis of diffusion obs: -0.0023335651881364328
# # diffusion obs: 948
# # pos jumps obs: 149
# # neg jumps obs: 149
# Skewness of diffusion obs: -0.0017635595923051308
# Excess kurtosis of diffusion obs: -0.1895390669938184
# # diffusion obs: 129
# # pos jumps obs: 308
# # neg jumps obs: 809
# Skewness of diffusion obs: -0.0010363077791446683
# Excess kurtosis of diffusion obs: -0.9431782591354607
# # diffusion obs: 948
# # pos jumps obs: 149
# # neg jumps obs: 149
# Skewness of diffusion obs: -0.0017635595923051308
# Excess kurtosis of diffusion obs: -0.1895390669938184
# # diffusion obs: 1022
# # pos jumps obs: 101
# # neg jumps obs: 123
# Skewness of diffusion obs: 0.0012387424229738703
# Excess kurtosis of diffusion obs: -0.05708965485783102
# # diffusion obs: 658
# # pos jumps obs: 314
# # neg jumps obs: 274
# Skewness of diffusion obs: 0.0007944576131511192
# Excess kurtosis of diffusion obs: -0.8519020360402458
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1246
# # pos jumps obs: 0
# # neg jumps obs: 0
# Skewness of diffusion obs: -0.26692284300326885
# Excess kurtosis of diffusion obs: 3.8806882294768936
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 915
# # pos jumps obs: 170
# # neg jumps obs: 161
# Skewness of diffusion obs: 0.0019788435564852716
# Excess kurtosis of diffusion obs: -0.287936538638331
# # diffusion obs: 957
# # pos jumps obs: 143
# # neg jumps obs: 146
# Skewness of diffusion obs: 9.582416119947209e-05
# Excess kurtosis of diffusion obs: -0.16575514399573654
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 988
# # pos jumps obs: 123
# # neg jumps obs: 135
# Skewness of diffusion obs: -0.002417520378970606
# Excess kurtosis of diffusion obs: -0.11384656975396279
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 911
# # pos jumps obs: 173
# # neg jumps obs: 162
# Skewness of diffusion obs: -0.004378336519104943
# Excess kurtosis of diffusion obs: -0.2974286470356433
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1246
# # pos jumps obs: 0
# # neg jumps obs: 0
# Skewness of diffusion obs: -0.26692284300326885
# Excess kurtosis of diffusion obs: 3.8806882294768936
# # diffusion obs: 1049
# # pos jumps obs: 85
# # neg jumps obs: 112
# Skewness of diffusion obs: 0.006976064583336136
# Excess kurtosis of diffusion obs: 0.010362641809913864
# # diffusion obs: 1049
# # pos jumps obs: 85
# # neg jumps obs: 112
# Skewness of diffusion obs: 0.006976064583336136
# Excess kurtosis of diffusion obs: 0.010362641809913864
# # diffusion obs: 1049
# # pos jumps obs: 85
# # neg jumps obs: 112
# Skewness of diffusion obs: 0.006976064583336136
# Excess kurtosis of diffusion obs: 0.010362641809913864
# # diffusion obs: 168
# # pos jumps obs: 69
# # neg jumps obs: 1009
# Skewness of diffusion obs: 0.6520770147181719
# Excess kurtosis of diffusion obs: -0.2555541854893577
# # diffusion obs: 1036
# # pos jumps obs: 93
# # neg jumps obs: 117
# Skewness of diffusion obs: -0.0032347659682246278
# Excess kurtosis of diffusion obs: -0.0273365449870262
# # diffusion obs: 1046
# # pos jumps obs: 87
# # neg jumps obs: 113
# Skewness of diffusion obs: 0.0018726017172954156
# Excess kurtosis of diffusion obs: 0.0012808248469493577
# # diffusion obs: 1046
# # pos jumps obs: 87
# # neg jumps obs: 113
# Skewness of diffusion obs: 0.0018726017172954156
# Excess kurtosis of diffusion obs: 0.0012808248469493577
# # diffusion obs: 1046
# # pos jumps obs: 87
# # neg jumps obs: 113
# Skewness of diffusion obs: 0.0018726017172954156
# Excess kurtosis of diffusion obs: 0.0012808248469493577
# # diffusion obs: 169
# # pos jumps obs: 69
# # neg jumps obs: 1008
# Skewness of diffusion obs: 0.6472711645755524
# Excess kurtosis of diffusion obs: -0.2593602758715927
# # diffusion obs: 1046
# # pos jumps obs: 87
# # neg jumps obs: 113
# Skewness of diffusion obs: 0.0018726017172954156
# Excess kurtosis of diffusion obs: 0.0012808248469493577
# # diffusion obs: 16
# # pos jumps obs: 0
# # neg jumps obs: 1230
# Skewness of diffusion obs: 1.101219915424681
# Excess kurtosis of diffusion obs: -0.569137319192548
# # diffusion obs: 16
# # pos jumps obs: 0
# # neg jumps obs: 1230
# Skewness of diffusion obs: 1.101219915424681
# Excess kurtosis of diffusion obs: -0.569137319192548
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1246
# # pos jumps obs: 0
# # neg jumps obs: 0
# Skewness of diffusion obs: -0.26692284300326885
# Excess kurtosis of diffusion obs: 3.8806882294768936
# # diffusion obs: 1041
# # pos jumps obs: 90
# # neg jumps obs: 115
# Skewness of diffusion obs: -0.0020369895637295282
# Excess kurtosis of diffusion obs: -0.01462004049156862
# # diffusion obs: 1121
# # pos jumps obs: 52
# # neg jumps obs: 73
# Skewness of diffusion obs: -0.0019746578205242045
# Excess kurtosis of diffusion obs: 0.3550277647829705
# # diffusion obs: 144
# # pos jumps obs: 70
# # neg jumps obs: 1032
# Skewness of diffusion obs: 0.7230271044761535
# Excess kurtosis of diffusion obs: -0.19811914020921062
# # diffusion obs: 142
# # pos jumps obs: 71
# # neg jumps obs: 1033
# Skewness of diffusion obs: 0.7056888402719683
# Excess kurtosis of diffusion obs: -0.22051411353914308
# # diffusion obs: 0
# # pos jumps obs: 85
# # neg jumps obs: 1171
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1045
# # pos jumps obs: 88
# # neg jumps obs: 113
# Skewness of diffusion obs: -0.004940351250212118
# Excess kurtosis of diffusion obs: -0.0011591258402208204
# # diffusion obs: 1124
# # pos jumps obs: 51
# # neg jumps obs: 71
# Skewness of diffusion obs: -0.008005660608355154
# Excess kurtosis of diffusion obs: 0.3688864947891015
# # diffusion obs: 145
# # pos jumps obs: 70
# # neg jumps obs: 1031
# Skewness of diffusion obs: 0.7193782025610389
# Excess kurtosis of diffusion obs: -0.2005827483160445
# # diffusion obs: 166
# # pos jumps obs: 69
# # neg jumps obs: 1011
# Skewness of diffusion obs: 0.6615126130901341
# Excess kurtosis of diffusion obs: -0.24816119434380024
# # diffusion obs: 0
# # pos jumps obs: 158
# # neg jumps obs: 1170
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 169
# # pos jumps obs: 69
# # neg jumps obs: 1008
# Skewness of diffusion obs: 0.6472711645755524
# Excess kurtosis of diffusion obs: -0.2593602758715927
# # diffusion obs: 144
# # pos jumps obs: 70
# # neg jumps obs: 1032
# Skewness of diffusion obs: 0.7230271044761535
# Excess kurtosis of diffusion obs: -0.19811914020921062
# # diffusion obs: 27
# # pos jumps obs: 50
# # neg jumps obs: 1169
# Skewness of diffusion obs: -0.09130424232534456
# Excess kurtosis of diffusion obs: -0.47871749833127764
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1246
# # pos jumps obs: 0
# # neg jumps obs: 0
# Skewness of diffusion obs: -0.26692284300326885
# Excess kurtosis of diffusion obs: 3.8806882294768936
# # diffusion obs: 17
# # pos jumps obs: 20
# # neg jumps obs: 1209
# Skewness of diffusion obs: 0.29568013258507864
# Excess kurtosis of diffusion obs: -0.33110002629162105
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 291
# # pos jumps obs: 23
# # neg jumps obs: 932
# Skewness of diffusion obs: 0.9396839479611411
# Excess kurtosis of diffusion obs: -0.0005408708050755884
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 128
# # pos jumps obs: 1067
# # neg jumps obs: 51
# Skewness of diffusion obs: -0.3652648506861849
# Excess kurtosis of diffusion obs: -0.66166917944334
# # diffusion obs: 294
# # pos jumps obs: 26
# # neg jumps obs: 926
# Skewness of diffusion obs: 0.9224575331117684
# Excess kurtosis of diffusion obs: -0.004951768653055133
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 161
# # pos jumps obs: 1067
# # neg jumps obs: 18
# Skewness of diffusion obs: -0.8903592378501771
# Excess kurtosis of diffusion obs: 0.0007865846061170245
# # diffusion obs: 291
# # pos jumps obs: 23
# # neg jumps obs: 932
# Skewness of diffusion obs: 0.9396839479611411
# Excess kurtosis of diffusion obs: -0.0005408708050755884
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 295
# # pos jumps obs: 26
# # neg jumps obs: 925
# Skewness of diffusion obs: 0.9225504802682752
# Excess kurtosis of diffusion obs: -0.002772037622918333
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 74
# # pos jumps obs: 13
# # neg jumps obs: 1159
# Skewness of diffusion obs: 0.697680512398633
# Excess kurtosis of diffusion obs: -0.21556159184114154
# # diffusion obs: 78
# # pos jumps obs: 12
# # neg jumps obs: 1156
# Skewness of diffusion obs: 0.7169115289752978
# Excess kurtosis of diffusion obs: -0.1920018764344853
# # diffusion obs: 78
# # pos jumps obs: 12
# # neg jumps obs: 1156
# Skewness of diffusion obs: 0.7169115289752978
# Excess kurtosis of diffusion obs: -0.1920018764344853
# # diffusion obs: 76
# # pos jumps obs: 12
# # neg jumps obs: 1158
# Skewness of diffusion obs: 0.7291207016171797
# Excess kurtosis of diffusion obs: -0.18237401872774361
# # diffusion obs: 79
# # pos jumps obs: 12
# # neg jumps obs: 1155
# Skewness of diffusion obs: 0.706998412533008
# Excess kurtosis of diffusion obs: -0.19799739882918255
# # diffusion obs: 78
# # pos jumps obs: 12
# # neg jumps obs: 1156
# Skewness of diffusion obs: 0.7169115289752978
# Excess kurtosis of diffusion obs: -0.1920018764344853
# # diffusion obs: 76
# # pos jumps obs: 12
# # neg jumps obs: 1158
# Skewness of diffusion obs: 0.7291207016171797
# Excess kurtosis of diffusion obs: -0.18237401872774361
# # diffusion obs: 78
# # pos jumps obs: 12
# # neg jumps obs: 1156
# Skewness of diffusion obs: 0.7169115289752978
# Excess kurtosis of diffusion obs: -0.1920018764344853
# # diffusion obs: 17
# # pos jumps obs: 4
# # neg jumps obs: 1225
# Skewness of diffusion obs: 0.02696109274757536
# Excess kurtosis of diffusion obs: -0.7587605104516029
# # diffusion obs: 10
# # pos jumps obs: 0
# # neg jumps obs: 1236
# Skewness of diffusion obs: 0.43448287781143397
# Excess kurtosis of diffusion obs: -1.6810136680884922
# # diffusion obs: 76
# # pos jumps obs: 12
# # neg jumps obs: 1158
# Skewness of diffusion obs: 0.7291207016171797
# Excess kurtosis of diffusion obs: -0.18237401872774361
# # diffusion obs: 78
# # pos jumps obs: 12
# # neg jumps obs: 1156
# Skewness of diffusion obs: 0.7169115289752978
# Excess kurtosis of diffusion obs: -0.1920018764344853
# # diffusion obs: 76
# # pos jumps obs: 12
# # neg jumps obs: 1158
# Skewness of diffusion obs: 0.7291207016171797
# Excess kurtosis of diffusion obs: -0.18237401872774361
# # diffusion obs: 41
# # pos jumps obs: 15
# # neg jumps obs: 1190
# Skewness of diffusion obs: 0.6347072479243276
# Excess kurtosis of diffusion obs: -0.4070418601418555
# # diffusion obs: 76
# # pos jumps obs: 12
# # neg jumps obs: 1158
# Skewness of diffusion obs: 0.7291207016171797
# Excess kurtosis of diffusion obs: -0.18237401872774361
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 1051
# # pos jumps obs: 84
# # neg jumps obs: 111
# Skewness of diffusion obs: 0.005543158483591431
# Excess kurtosis of diffusion obs: 0.01800055281597901
# # diffusion obs: 68
# # pos jumps obs: 764
# # neg jumps obs: 414
# Skewness of diffusion obs: -0.001823089625672655
# Excess kurtosis of diffusion obs: -0.8632430058373313
# # diffusion obs: 3
# # pos jumps obs: 0
# # neg jumps obs: 1243
# Skewness of diffusion obs: 0.5766444420510485
# Excess kurtosis of diffusion obs: -1.5000000000000102
# # diffusion obs: 135
# # pos jumps obs: 5
# # neg jumps obs: 1106
# Skewness of diffusion obs: 0.9180595571316561
# Excess kurtosis of diffusion obs: -0.005631817541160267
# # diffusion obs: 11
# # pos jumps obs: 5
# # neg jumps obs: 1230
# Skewness of diffusion obs: 0.06448257986607842
# Excess kurtosis of diffusion obs: -0.6260527403793446
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 11
# # pos jumps obs: 5
# # neg jumps obs: 1230
# Skewness of diffusion obs: 0.06448257986607842
# Excess kurtosis of diffusion obs: -0.6260527403793446
# # diffusion obs: 134
# # pos jumps obs: 5
# # neg jumps obs: 1107
# Skewness of diffusion obs: 0.9131830229416507
# Excess kurtosis of diffusion obs: -0.014017201366199217
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 17
# # pos jumps obs: 20
# # neg jumps obs: 1209
# Skewness of diffusion obs: 0.29568013258507864
# Excess kurtosis of diffusion obs: -0.33110002629162105
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 135
# # pos jumps obs: 5
# # neg jumps obs: 1106
# Skewness of diffusion obs: 0.9180595571316561
# Excess kurtosis of diffusion obs: -0.005631817541160267
# # diffusion obs: 135
# # pos jumps obs: 5
# # neg jumps obs: 1106
# Skewness of diffusion obs: 0.9180595571316561
# Excess kurtosis of diffusion obs: -0.005631817541160267
# # diffusion obs: 134
# # pos jumps obs: 5
# # neg jumps obs: 1107
# Skewness of diffusion obs: 0.9131830229416507
# Excess kurtosis of diffusion obs: -0.014017201366199217
# # diffusion obs: 11
# # pos jumps obs: 5
# # neg jumps obs: 1230
# Skewness of diffusion obs: 0.06448257986607842
# Excess kurtosis of diffusion obs: -0.6260527403793446
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 43
# # pos jumps obs: 1180
# # neg jumps obs: 23
# Skewness of diffusion obs: -0.39714401543423694
# Excess kurtosis of diffusion obs: -0.6139786209020461
# # diffusion obs: 39
# # pos jumps obs: 1181
# # neg jumps obs: 26
# Skewness of diffusion obs: -0.20178350223622302
# Excess kurtosis of diffusion obs: -0.8907128364077246
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 17
# # pos jumps obs: 4
# # neg jumps obs: 1225
# Skewness of diffusion obs: 0.02696109274757536
# Excess kurtosis of diffusion obs: -0.7587605104516029
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 17
# # pos jumps obs: 4
# # neg jumps obs: 1225
# Skewness of diffusion obs: 0.02696109274757536
# Excess kurtosis of diffusion obs: -0.7587605104516029
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 43
# # pos jumps obs: 1180
# # neg jumps obs: 23
# Skewness of diffusion obs: -0.39714401543423694
# Excess kurtosis of diffusion obs: -0.6139786209020461
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 3
# # pos jumps obs: 0
# # neg jumps obs: 1243
# Skewness of diffusion obs: 0.5766444420510485
# Excess kurtosis of diffusion obs: -1.5000000000000102
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 44
# # pos jumps obs: 1180
# # neg jumps obs: 22
# Skewness of diffusion obs: -0.4822059311860964
# Excess kurtosis of diffusion obs: -0.4990628614512085
# # diffusion obs: 178
# # pos jumps obs: 1049
# # neg jumps obs: 19
# Skewness of diffusion obs: -0.8656138282719719
# Excess kurtosis of diffusion obs: -0.007202120357707731
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 11
# # pos jumps obs: 5
# # neg jumps obs: 1230
# Skewness of diffusion obs: 0.06448257986607842
# Excess kurtosis of diffusion obs: -0.6260527403793446
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 178
# # pos jumps obs: 1049
# # neg jumps obs: 19
# Skewness of diffusion obs: -0.8656138282719719
# Excess kurtosis of diffusion obs: -0.007202120357707731
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 3
# # pos jumps obs: 0
# # neg jumps obs: 1243
# Skewness of diffusion obs: 0.5766444420510485
# Excess kurtosis of diffusion obs: -1.5000000000000102
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 179
# # pos jumps obs: 1043
# # neg jumps obs: 24
# Skewness of diffusion obs: -0.7346839175597776
# Excess kurtosis of diffusion obs: -0.31556283870573054
# # diffusion obs: 177
# # pos jumps obs: 1050
# # neg jumps obs: 19
# Skewness of diffusion obs: -0.8657672196665442
# Excess kurtosis of diffusion obs: -0.0086434424135855
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 4
# # pos jumps obs: 0
# # neg jumps obs: 1242
# Skewness of diffusion obs: 0.5472675584622215
# Excess kurtosis of diffusion obs: -1.0103220499186574
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 1246
# # neg jumps obs: 0
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 3
# # pos jumps obs: 0
# # neg jumps obs: 1243
# Skewness of diffusion obs: 0.5766444420510485
# Excess kurtosis of diffusion obs: -1.5000000000000102
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan
# # diffusion obs: 0
# # pos jumps obs: 0
# # neg jumps obs: 1246
# Skewness of diffusion obs: nan
# Excess kurtosis of diffusion obs: nan

# %%
POT_results = POT_results.sort_values('error')
POT_results
# Out:
#      nu_p0  nu_m0      nu_p      nu_m     eta_p     eta_m      skew      kurt  \
# 101  0.054  0.000  0.053331 -0.046207  0.031186  0.034054  0.001873  0.001281
# 99   0.054 -0.036  0.053331 -0.046144  0.031186  0.034117  0.001873  0.001281
# 98   0.054 -0.054  0.053322 -0.046107  0.031195  0.034154  0.001873  0.001281
# 97   0.054 -0.072  0.053318 -0.046244  0.031199  0.034017  0.001873  0.001281
# 111  0.072 -0.072  0.053288 -0.046184  0.030875  0.034078 -0.004940 -0.001159
# ..     ...    ...       ...       ...       ...       ...       ...       ...
# 226  0.180  0.108  5.355858  2.840149       NaN  2.837730       NaN       NaN
# 227  0.180  0.126  2.767929  2.713929       NaN  2.711509       NaN       NaN
# 228  0.180  0.144  2.767929  2.731929       NaN  2.729509       NaN       NaN
# 229  0.180  0.162  2.767929  2.749929       NaN  2.747509       NaN       NaN
# 230  0.180  0.180  2.767929  2.767929       NaN  2.765509       NaN       NaN
#
#      n_pos_jumps  n_neg_jumps  percentage_diffusion     error
# 101           87          113              0.838813  0.000005
# 99            87          113              0.838813  0.000005
# 98            87          113              0.838813  0.000005
# 97            87          113              0.838813  0.000005
# 111           88          113              0.838011  0.000026
# ..           ...          ...                   ...       ...
# 226            0         1246              0.000000       NaN
# 227            0         1246              0.000000       NaN
# 228            0         1246              0.000000       NaN
# 229            0         1246              0.000000       NaN
# 230            0         1246              0.000000       NaN
#
# [231 rows x 12 columns]

# %%
nu_p = POT_results.iloc[0].nu_p
nu_m = POT_results.iloc[0].nu_m

eta_p = POT_results.iloc[0].eta_p
eta_m = POT_results.iloc[0].eta_m

# Plug in calibrated nu_p and nu_m
MLE_estimator_daily.run_Peak_over_Thresholds(nu_m, nu_p, plug_in_nus=True)

# Calibrate mu and sigma
MLE_estimator_daily.calibrate_mu_and_sigma()
print('daily mu:', MLE_estimator_daily.mu, 'daily sigma:', MLE_estimator_daily.sigma)

# %%
MLE_estimator_daily.calibrate_Hawkes_params(pars0 = (5, 400, 5, 400, 100, -100, 100, -100))
MLE_estimator_daily.Hawkes_results

# %%
MLE_estimator_daily.calibrate_mu_and_sigma()
mu = MLE_estimator_daily.mu
sigma = MLE_estimator_daily.sigma

# %%
# Retrieve calibration result
theta_p, kappa_p, theta_m, kappa_m, beta11, beta12, beta21, beta22 = MLE_estimator_daily.Hawkes_results.x

# %%
# generalise intensities to the whole price path
lambdas_paths = returns.copy()
lambdas_paths.name = 'returns'
lambdas_paths = pd.DataFrame(lambdas_paths)
lambdas_paths.loc[:,'jump_sizes'] = 0

# assign jump sizes
_id = lambdas_paths.returns >= nu_p
lambdas_paths.jump_sizes[_id] = lambdas_paths.returns[_id]

# assign jump sizes
_id = lambdas_paths.returns <= nu_m
lambdas_paths.jump_sizes[_id] = lambdas_paths.returns[_id]

lambdas_paths.loc[:,'t'] = (lambdas_paths.index - lambdas_paths.index[0])
lambdas_paths.t = lambdas_paths.t.apply(lambda x: x.total_seconds()/SECONDS_PER_YEAR)

timestamps = pd.Series(lambdas_paths.index)

# %%
lambda_p_left_arr = [theta_p]
lambda_m_left_arr = [theta_m]

lambda_p_right_arr = [theta_p]
lambda_m_right_arr = [theta_m]

for i in range(1, len(lambdas_paths)):
    _T = lambdas_paths.t.iloc[i-1]
    _lambda_p_T_right = lambda_p_right_arr[-1]
    _lambda_m_T_right = lambda_m_right_arr[-1]

    T = lambdas_paths.t.iloc[i]
    jump_size = lambdas_paths.jump_sizes.iloc[i]
    lambda_p_T_left  = (_lambda_p_T_right - theta_p)*np.exp(-kappa_p*(T - _T)) + theta_p
    lambda_m_T_left  = (_lambda_m_T_right - theta_m)*np.exp(-kappa_m*(T - _T)) + theta_m

    if jump_size > 0:
        lambda_p_T_right = lambda_p_T_left + beta11*jump_size
        lambda_m_T_right = lambda_m_T_left + beta21*jump_size
    else:
        lambda_p_T_right = lambda_p_T_left + beta12*jump_size
        lambda_m_T_right = lambda_m_T_left + beta22*jump_size

    lambda_p_left_arr.append(lambda_p_T_left)
    lambda_m_left_arr.append(lambda_m_T_left)

    lambda_p_right_arr.append(lambda_p_T_right)
    lambda_m_right_arr.append(lambda_m_T_right)

lambdas_paths.loc[:,'lambda_p_left'] = lambda_p_left_arr
lambdas_paths.loc[:,'lambda_m_left'] = lambda_m_left_arr

lambdas_paths.loc[:,'lambda_p_right'] = lambda_p_right_arr
lambdas_paths.loc[:,'lambda_m_right'] = lambda_m_right_arr

# %%
lambdas_paths.loc[:,'theta_p'] = theta_p
lambdas_paths.loc[:,'theta_m'] = theta_m
lambdas_paths.loc[:,'kappa_p'] = kappa_p
lambdas_paths.loc[:,'kappa_m'] = kappa_m
lambdas_paths.loc[:,'beta11'] = beta11
lambdas_paths.loc[:,'beta12'] = beta12
lambdas_paths.loc[:,'beta21'] = beta21
lambdas_paths.loc[:,'beta22'] = beta22
lambdas_paths.loc[:,'eta_p'] = eta_p
lambdas_paths.loc[:,'eta_m'] = eta_m
lambdas_paths.loc[:,'nu_p'] = nu_p
lambdas_paths.loc[:,'nu_m'] = nu_m

# %%
lambdas_paths.loc[:, 'mu'] = MLE_estimator_daily.mu
lambdas_paths.loc[:, 'sigma'] = MLE_estimator_daily.sigma

# %%
lambdas_paths.to_csv('P_params.csv')
